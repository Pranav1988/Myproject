# %%
import pandas as pd

# %% [markdown]
# #  Importing __Actors__ Ranking file which contains infromation for actors rgarding their rankings,movie count.

# %%
csv_file_actors = pd.read_csv("D:\SpringBoard_Home\Capstone_Project_1\Data\BollywoodActorRanking.csv")

# %%
csv_file_actors.reset_index(drop = True)
# Out:
#      actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0        373        Aamir Khan          11       1170              9.44862
# 1        374    Shah Rukh Khan          23       2000              7.55009
# 2        375       Salman Khan          36       2340              5.40217
# 3        376      Katrina Kaif          17       1640              8.48082
# 4        377  Deepika Padukone          16       1080              5.64674
# ..       ...               ...         ...        ...                  ...
# 296      669       Achint Kaur           4         80              1.00000
# 297      670   Yuvika Chaudhry           5        100              1.00000
# 298      671      Pankaj Berry           5        100              1.00000
# 299      672      Varun Dhawan           0          0                  NaN
# 300      673     Nargis Fakhri           0          0                  NaN
#
#      googleHits  normalizedGoogleRank  normalizedRating
# 0       2460000               7.34283          10.00000
# 1       2670000               7.88458           9.22674
# 2       3490000              10.00000           9.20821
# 3       2120000               6.46570           8.94852
# 4       3000000               8.73591           8.62716
# ..          ...                   ...               ...
# 296           0                   NaN           1.00000
# 297           0                   NaN           1.00000
# 298           0                   NaN           1.00000
# 299           0                   NaN           4.74000
# 300           0                   NaN           4.80000
#
# [301 rows x 8 columns]

# %%
csv_file_actors.describe()
# Out:
#           actorId  movieCount    ratingSum  normalizedMovieRank    googleHits  \
# count  301.000000  301.000000   301.000000           299.000000  3.010000e+02
# mean   523.000000   10.232558   419.136213             2.768970  3.741886e+05
# std     87.035433    8.508764   446.972689             1.626970  6.647169e+05
# min    373.000000    0.000000     0.000000             1.000000  0.000000e+00
# 25%    448.000000    5.000000   140.000000             1.489130  0.000000e+00
# 50%    523.000000    7.000000   260.000000             2.369570  7.640000e+04
# 75%    598.000000   12.000000   500.000000             3.621045  3.850000e+05
# max    673.000000   54.000000  2950.000000            10.000000  3.490000e+06
#
#        normalizedGoogleRank  normalizedRating
# count            189.000000        301.000000
# mean               2.533937          2.933339
# std                1.951501          1.747883
# min                1.000000          1.000000
# 25%                1.242680          1.709770
# 50%                1.638930          2.493970
# 75%                2.967520          3.559640
# max               10.000000         10.000000

# %%
csv_file_actors.info()

# normalizedMovieRank has 2 null values - Removed(Movies count were zero for two actors)
# normalisedGoogleRank has 112 null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   actorId               301 non-null    int64
#  1   actorName             301 non-null    object
#  2   movieCount            301 non-null    int64
#  3   ratingSum             301 non-null    int64
#  4   normalizedMovieRank   299 non-null    float64
#  5   googleHits            301 non-null    int64
#  6   normalizedGoogleRank  189 non-null    float64
#  7   normalizedRating      301 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 18.9+ KB

# %%
csv_file_actors.actorName.count()
# Out:
# 301

# %% [markdown]
# => Removing two rows where there are 0 movies counts and having __'NA'__ normalizedMovieRank.

# %%
csv_file_actors = csv_file_actors.dropna(subset = ['normalizedMovieRank'])

# %% [markdown]
# => Replacing __"NA"__ with __"0"__ for normalizedGoogleRank column

# %%
csv_file_actors[csv_file_actors.normalizedGoogleRank.isnull()==True]
csv_file_actors['normalizedGoogleRank'].fillna(value = 0,inplace = True)
csv_file_actors
# Out:
#      actorId         actorName  movieCount  ratingSum  normalizedMovieRank  \
# 0        373        Aamir Khan          11       1170              9.44862
# 1        374    Shah Rukh Khan          23       2000              7.55009
# 2        375       Salman Khan          36       2340              5.40217
# 3        376      Katrina Kaif          17       1640              8.48082
# 4        377  Deepika Padukone          16       1080              5.64674
# ..       ...               ...         ...        ...                  ...
# 294      667        Tanvi Azmi           4         80              1.00000
# 295      668         Adi Irani           4         80              1.00000
# 296      669       Achint Kaur           4         80              1.00000
# 297      670   Yuvika Chaudhry           5        100              1.00000
# 298      671      Pankaj Berry           5        100              1.00000
#
#      googleHits  normalizedGoogleRank  normalizedRating
# 0       2460000               7.34283          10.00000
# 1       2670000               7.88458           9.22674
# 2       3490000              10.00000           9.20821
# 3       2120000               6.46570           8.94852
# 4       3000000               8.73591           8.62716
# ..          ...                   ...               ...
# 294           0               0.00000           1.00000
# 295           0               0.00000           1.00000
# 296           0               0.00000           1.00000
# 297           0               0.00000           1.00000
# 298           0               0.00000           1.00000
#
# [299 rows x 8 columns]

# %% [markdown]
# # Director Ranking File with information for each director regarding movie count and other rankings

# %%
Directors = pd.read_csv("D:\SpringBoard_Home\Capstone_Project_1\Data\BollywoodDirectorRanking.csv")

# %%
Directors
# Out:
#      directorId     directorName  movieCount  ratingSum  normalizedMovieRank  \
# 0             1  Rajkumar Hirani           3        440             10.00000
# 1             2       Farah Khan           4        440              7.39474
# 2             3      Karan Johar           5        430              5.68947
# 3             4       Sajid Khan           4        350              5.79605
# 4             5     Rohit Shetty          10        950              6.32895
# ..          ...              ...         ...        ...                  ...
# 113         114     Shyam Ramsay           3         60              1.00000
# 114         115      Jag Mundhra           3         60              1.00000
# 115         116    Kalpana Lajmi           3         60              1.00000
# 116         117    Ajay Chandhok           4         80              1.00000
# 117         118      Puneet Sira           3         60              1.00000
#
#      googleHits  normalizedGoogleRank  normalizedRating
# 0        146000               2.07796          10.00000
# 1       1060000               8.88317           8.78473
# 2       1050000               8.80872           7.10460
# 3        905000               7.72912           6.99780
# 4        437000               4.24461           6.83761
# ..          ...                   ...               ...
# 113        9930               1.06485           1.01149
# 114        6710               1.04088           1.00681
# 115        4380               1.02353           1.00342
# 116        2420               1.00893           1.00057
# 117        2030               1.00603           1.00000
#
# [117 rows x 8 columns]

# %%
Directors.info()

## directorname has 1 null value.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   directorId            118 non-null    int64
#  1   directorName          117 non-null    object
#  2   movieCount            118 non-null    int64
#  3   ratingSum             118 non-null    int64
#  4   normalizedMovieRank   118 non-null    float64
#  5   googleHits            118 non-null    int64
#  6   normalizedGoogleRank  118 non-null    float64
#  7   normalizedRating      118 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 7.5+ KB

# %%
NaN_directors = Directors[Directors.directorName.isnull()== True]

# %%
NaN_directors
# Out:
#      directorId directorName  movieCount  ratingSum  normalizedMovieRank  \
# 103         104          NaN           7        180              1.40602
#
#      googleHits  normalizedGoogleRank  normalizedRating
# 103           0                   0.0           1.20004

# %% [markdown]
# => Removing row with "__null__" Director name

# %%
Directors = Directors.dropna()
Directors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 117
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   directorId            117 non-null    int64
#  1   directorName          117 non-null    object
#  2   movieCount            117 non-null    int64
#  3   ratingSum             117 non-null    int64
#  4   normalizedMovieRank   117 non-null    float64
#  5   googleHits            117 non-null    int64
#  6   normalizedGoogleRank  117 non-null    float64
#  7   normalizedRating      117 non-null    float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 8.2+ KB

# %%
Directors.head()
# Out:
#    directorId     directorName  movieCount  ratingSum  normalizedMovieRank  \
# 0           1  Rajkumar Hirani           3        440             10.00000
# 1           2       Farah Khan           4        440              7.39474
# 2           3      Karan Johar           5        430              5.68947
# 3           4       Sajid Khan           4        350              5.79605
# 4           5     Rohit Shetty          10        950              6.32895
#
#    googleHits  normalizedGoogleRank  normalizedRating
# 0      146000               2.07796          10.00000
# 1     1060000               8.88317           8.78473
# 2     1050000               8.80872           7.10460
# 3      905000               7.72912           6.99780
# 4      437000               4.24461           6.83761

# %% [markdown]
# # Movies File - Information for each movie

# %%
Movie = pd.read_csv("D:\SpringBoard_Home\Capstone_Project_1\Data\BollywoodMovieDetail.csv")

# %%
Movie
# Out:
#          imdbId                              title  releaseYear  releaseDate  \
# 0     tt0118578                             Albela         2001  20 Apr 2001
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2     tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3     tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4     tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# ...         ...                                ...          ...          ...
# 1279  tt4121522               Shuruaat Ka Interval         2014  15 Aug 2014
# 1280  tt4187650                   Trip to Bhangarh         2014  28 Aug 2014
# 1281  tt4190220                           Zed Plus         2014  28 Nov 2014
# 1282  tt4219300                    Gollu aur Pappu         2014  21 Nov 2014
# 1283  tt4228746                                Zid         2014  28 Nov 2014
#
#                             genre  \
# 0                         Romance
# 1     Adventure | Drama | Musical
# 2                 Action | Comedy
# 3                 Drama | Romance
# 4         Action | Comedy | Drama
# ...                           ...
# 1279                          NaN
# 1280                       Horror
# 1281                          NaN
# 1282                       Comedy
# 1283                     Thriller
#
#                                                 writers  \
# 0     Honey Irani (screenplay) | Honey Irani (story)...
# 1     Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                   NaN
# 3     K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4     Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
# ...                                                 ...
# 1279  Aarti S. Bagdi | Amrit Raj Gupta | Krishan Hoo...
# 1280                                                NaN
# 1281  Chandra Prakash Dwivedi (screen play and dialo...
# 1282                                                NaN
# 1283                   Vivek Agnihotri | Rohit Malhotra
#
#                                                  actors  \
# 0     Govinda | Aishwarya Rai Bachchan | Jackie Shro...
# 1     Aamir Khan | Gracy Singh | Rachel Shelley | Pa...
# 2     Akshay Kumar | Sridevi | Gulshan Grover | Laxm...
# 3     Shah Rukh Khan | Madhuri Dixit | Salman Khan |...
# 4     Shah Rukh Khan | Juhi Chawla | Jackie Shroff |...
# ...                                                 ...
# 1279  Kaivalya Chheda | Rajsekhar Aningi | Avidant B...
# 1280  Manish Choudhary | Suzanna Mukherjee | Poonam ...
# 1281  Adil Hussain | Ekavali Khanna | Kulbhushan Kha...
# 1282  Vir Das | Sandeepa Dhar | Rahul Handa | Dimple...
# 1283  Shradha Das | Mohan Kapoor | Mannara | Karanvi...
#
#                                               directors  sequel  hitFlop
# 0                                         Deepak Sareen     0.0        2
# 1                                    Ashutosh Gowariker     0.0        6
# 2                          Pankaj Parashar | S.M. Iqbal     0.0        1
# 3                                         K.S. Adiyaman     0.0        4
# 4                                     Shashilal K. Nair     0.0        1
# ...                                                 ...     ...      ...
# 1279  Aarti S. Bagdi | Amrit Raj Gupta | Krishan Hoo...     0.0        1
# 1280                                     Jitendra Pawar     0.0        1
# 1281                            Chandra Prakash Dwivedi     0.0        1
# 1282                                     Kabir Sadanand     0.0        1
# 1283                     Rohit Malhotra | Anubhav Sinha     0.0        2
#
# [1284 rows x 10 columns]

# %%
Movie.info()
# releaseDate column has 53 null
# genre has 2 Null
# Writers has 119 Null
# actors has 3 Null
# directors has 4 Null
# sequel has 3 Null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdbId       1284 non-null   object
#  1   title        1284 non-null   object
#  2   releaseYear  1284 non-null   int64
#  3   releaseDate  1231 non-null   object
#  4   genre        1282 non-null   object
#  5   writers      1165 non-null   object
#  6   actors       1281 non-null   object
#  7   directors    1280 non-null   object
#  8   sequel       1281 non-null   float64
#  9   hitFlop      1284 non-null   int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 100.4+ KB

# %% [markdown]
# => Dropping rows having released date __null__.

# %%
Drop_Movie = Movie.drop(Movie[Movie.releaseDate.isnull() == True].index,axis= 0)

# %% [markdown]
# => Taking null rows seperated from "Movie" data and then removing column __"releaseDate"__

# %%
Missing_Date = Movie[Movie.releaseDate.isnull() == True]
Removed_Date = Missing_Date.drop(['releaseDate'],axis =1)

# %%
Removed_Date.head(2)
# Out:
#        imdbId                  title  releaseYear                      genre  \
# 22  tt0273535  Dil Ne Phir Yaad Kiya         2001  Drama | Musical | Romance
# 57  tt0303187          Veer Savarkar         2001          Biography | Drama
#
#      writers                                             actors     directors  \
# 22       NaN  Sadashiv Amrapurkar | Vinay Anand | Pooja Batr...  Rajat Rawail
# 57  Ved Rahi  Shailendra Gaur | Pankaj Berry | Tom Alter | H...      Ved Rahi
#
#     sequel  hitFlop
# 22     0.0        1
# 57     0.0        1

# %% [markdown]
# => Importing file with dates filled for null rows for released Date.

# %%
Dates_fill = pd.read_csv("D:\SpringBoard_Home\Capstone_Project_1\Data\Missing\missing.csv")
Dates_fill.head(2)
# Out:
#    Unnamed: 0     imdbId                  title  releaseYear releaseDate  \
# 0          22  tt0273535  Dil Ne Phir Yaad Kiya         2001    7-Sep-01
# 1          57  tt0303187          Veer Savarkar         2001   16-Nov-01
#
#                        genre   writers  \
# 0  Drama | Musical | Romance       NaN
# 1          Biography | Drama  Ved Rahi
#
#                                               actors     directors  sequel  \
# 0  Sadashiv Amrapurkar | Vinay Anand | Pooja Batr...  Rajat Rawail       0
# 1  Shailendra Gaur | Pankaj Berry | Tom Alter | H...      Ved Rahi       0
#
#    hitFlop
# 0        1
# 1        1

# %% [markdown]
# => Merge Two datafrmaes - Removed Dates and Dates_fill which has all dates filled in for missing rows.

# %%
Result = pd.merge(Removed_Date,Dates_fill[['imdbId','releaseDate']])

# %%
Result.head(2)
# Out:
#       imdbId                  title  releaseYear                      genre  \
# 0  tt0273535  Dil Ne Phir Yaad Kiya         2001  Drama | Musical | Romance
# 1  tt0303187          Veer Savarkar         2001          Biography | Drama
#
#     writers                                             actors     directors  \
# 0       NaN  Sadashiv Amrapurkar | Vinay Anand | Pooja Batr...  Rajat Rawail
# 1  Ved Rahi  Shailendra Gaur | Pankaj Berry | Tom Alter | H...      Ved Rahi
#
#    sequel  hitFlop releaseDate
# 0     0.0        1    7-Sep-01
# 1     0.0        1   16-Nov-01

# %% [markdown]
# => Move Position of releaseDate as per Old dataframe

# %%
Result.columns
# Out:
# Index(['imdbId', 'title', 'releaseYear', 'genre', 'writers', 'actors',
#        'directors', 'sequel', 'hitFlop', 'releaseDate'],
#       dtype='object')

# %%
Result = Result[['imdbId', 'title', 'releaseYear','releaseDate', 'genre', 'writers', 'actors',
       'directors', 'sequel', 'hitFlop' ]]

# %%
Result.head(2)
# Out:
#       imdbId                  title  releaseYear releaseDate  \
# 0  tt0273535  Dil Ne Phir Yaad Kiya         2001    7-Sep-01
# 1  tt0303187          Veer Savarkar         2001   16-Nov-01
#
#                        genre   writers  \
# 0  Drama | Musical | Romance       NaN
# 1          Biography | Drama  Ved Rahi
#
#                                               actors     directors  sequel  \
# 0  Sadashiv Amrapurkar | Vinay Anand | Pooja Batr...  Rajat Rawail     0.0
# 1  Shailendra Gaur | Pankaj Berry | Tom Alter | H...      Ved Rahi     0.0
#
#    hitFlop
# 0        1
# 1        1

# %% [markdown]
# => Finally merge datframe having dates filled with Original data

# %%
Final_Movie =  pd.merge(Drop_Movie,Result,how = 'outer')

# %% [markdown]
# => Filling correct genres for movies

# %%
## Genre

Final_Movie[Final_Movie.genre.isnull()==True]


Final_Movie.at[1226,'genre'] = 'Drama'
Final_Movie.at[1228,'genre'] = 'Romance | Drama'

# %% [markdown]
# => Fill actors with correct strings

# %%
# Actors

Final_Movie[Final_Movie.actors.isnull() == True]
Final_Movie.at[751,'actors'] = 'Shakeel Bharati | Farogh Jafri'

# %% [markdown]
# => Filling directors with correct names

# %%
# Directors

#Fill Directors with correct strings

Final_Movie[Final_Movie.directors.isnull() == True]

Final_Movie.at[198,'directors'] = 'Tarun Wadhwa'
Final_Movie.at[281,'directors'] = 'T. L. V. Prasad'
Final_Movie.at[409,'directors'] = 'Partho Ghosh'
Final_Movie.at[1262,'directors'] = 'P Jitendra'

# %% [markdown]
# => Filling __"Na"__ with __0__ for sequel column.

# %%
Final_Movie[Final_Movie.sequel.isnull() == True]

Final_Movie['sequel'].fillna(0,inplace = True)

# %%
# releaseDate has 2 Null values -cannot find on internet
# actors has 2 Null values - Animation movies has no actor

Final_Movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1284 entries, 0 to 1283
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdbId       1284 non-null   object
#  1   title        1284 non-null   object
#  2   releaseYear  1284 non-null   int64
#  3   releaseDate  1282 non-null   object
#  4   genre        1284 non-null   object
#  5   writers      1165 non-null   object
#  6   actors       1282 non-null   object
#  7   directors    1284 non-null   object
#  8   sequel       1284 non-null   float64
#  9   hitFlop      1284 non-null   int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 150.3+ KB

# %%
## Final_Movie[Final_Movie.directors == 'Maneesh Sharma'].replace(to_replace = [0,0,0],value = 0)

# %% [markdown]
# # Cleaned Movie Dataframe

# %%
Final_Movie
# Out:
#          imdbId                              title  releaseYear  releaseDate  \
# 0     tt0118578                             Albela         2001  20 Apr 2001
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2     tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3     tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4     tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# ...         ...                                ...          ...          ...
# 1279  tt1612574            Sanam Hum Aapke Hain...         2009     1-Jan-09
# 1280  tt1806740                           9 Eleven         2011     7-Oct-11
# 1281  tt2035528                     Hum Do Anjaane         2011    27-May-11
# 1282  tt2150074                            Koi Hai         2003     6-Jun-03
# 1283  tt2182726                              Hansa         2012    28-Dec-12
#
#                             genre  \
# 0                         Romance
# 1     Adventure | Drama | Musical
# 2                 Action | Comedy
# 3                 Drama | Romance
# 4         Action | Comedy | Drama
# ...                           ...
# 1279              Drama | Romance
# 1280                     Thriller
# 1281       Action | Crime | Drama
# 1282               Drama | Horror
# 1283                        Drama
#
#                                                 writers  \
# 0     Honey Irani (screenplay) | Honey Irani (story)...
# 1     Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                   NaN
# 3     K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4     Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
# ...                                                 ...
# 1279  Dhananjay (dialogues) | Murari Kishan (lyrics)...
# 1280                                     Manan Katohora
# 1281   Milind Swamy (screenplay) | Milind Swamy (story)
# 1282                    Manoj Hansraj | Rajiv S.S. Ruia
# 1283                                                NaN
#
#                                                  actors  \
# 0     Govinda | Aishwarya Rai Bachchan | Jackie Shro...
# 1     Aamir Khan | Gracy Singh | Rachel Shelley | Pa...
# 2     Akshay Kumar | Sridevi | Gulshan Grover | Laxm...
# 3     Shah Rukh Khan | Madhuri Dixit | Salman Khan |...
# 4     Shah Rukh Khan | Juhi Chawla | Jackie Shroff |...
# ...                                                 ...
# 1279  Vikram Aditya | Narendra Bedi | Chandan | Arad...
# 1280  Kashmira Shah | Devasish Ray | Jyoti Singh | S...
# 1281  Naresh Kaura | Ankita Bhargava | Jackie Shroff...
# 1282  Aman Verma | Shweta Menon | Rinku Ghosh | Roop...
# 1283  Trimala Adhikari | Abhay Joshi | Ashish Kumar ...
#
#                          directors  sequel  hitFlop
# 0                    Deepak Sareen     0.0        2
# 1               Ashutosh Gowariker     0.0        6
# 2     Pankaj Parashar | S.M. Iqbal     0.0        1
# 3                    K.S. Adiyaman     0.0        4
# 4                Shashilal K. Nair     0.0        1
# ...                            ...     ...      ...
# 1279                     Ajay Ojha     0.0        1
# 1280                Manan Katohora     0.0        1
# 1281                  Milind Swamy     0.0        1
# 1282                 Rajiv S. Ruia     0.0        1
# 1283                    Manav Kaul     0.0        1
#
# [1284 rows x 10 columns]

# %%
Final_Movie['actors'][0]
# Out:
# 'Govinda | Aishwarya Rai Bachchan | Jackie Shroff | Namrata Shirodkar'

# %% [markdown]
# # Creating list from Actors column and making multiple rows

# %%
Final_Movie_Actors = Final_Movie.copy()

# %%
# Split strings into list
    
Final_Movie_Actors['Actor'] = Final_Movie['actors'].str.split('|')


# Convert list into seperate rows

Final_Movie_Actors = Final_Movie_Actors.explode('Actor')

#Removed un-necessary columns
Final_Movie_Actors = Final_Movie_Actors.drop(['actors','imdbId'],axis = 'columns')

# Remove all  spaces
Final_Movie_Actors['Actor'] = Final_Movie_Actors['Actor'].str.strip()

Final_Movie_Actors
# Out:
#                                   title  releaseYear  releaseDate  \
# 0                                Albela         2001  20 Apr 2001
# 0                                Albela         2001  20 Apr 2001
# 0                                Albela         2001  20 Apr 2001
# 0                                Albela         2001  20 Apr 2001
# 1     Lagaan: Once Upon a Time in India         2001  08 May 2002
# ...                                 ...          ...          ...
# 1282                            Koi Hai         2003     6-Jun-03
# 1283                              Hansa         2012    28-Dec-12
# 1283                              Hansa         2012    28-Dec-12
# 1283                              Hansa         2012    28-Dec-12
# 1283                              Hansa         2012    28-Dec-12
#
#                             genre  \
# 0                         Romance
# 0                         Romance
# 0                         Romance
# 0                         Romance
# 1     Adventure | Drama | Musical
# ...                           ...
# 1282               Drama | Horror
# 1283                        Drama
# 1283                        Drama
# 1283                        Drama
# 1283                        Drama
#
#                                                 writers           directors  \
# 0     Honey Irani (screenplay) | Honey Irani (story)...       Deepak Sareen
# 0     Honey Irani (screenplay) | Honey Irani (story)...       Deepak Sareen
# 0     Honey Irani (screenplay) | Honey Irani (story)...       Deepak Sareen
# 0     Honey Irani (screenplay) | Honey Irani (story)...       Deepak Sareen
# 1     Ashutosh Gowariker (story) | Ashutosh Gowarike...  Ashutosh Gowariker
# ...                                                 ...                 ...
# 1282                    Manoj Hansraj | Rajiv S.S. Ruia       Rajiv S. Ruia
# 1283                                                NaN          Manav Kaul
# 1283                                                NaN          Manav Kaul
# 1283                                                NaN          Manav Kaul
# 1283                                                NaN          Manav Kaul
#
#       sequel  hitFlop                   Actor
# 0        0.0        2                 Govinda
# 0        0.0        2  Aishwarya Rai Bachchan
# 0        0.0        2           Jackie Shroff
# 0        0.0        2       Namrata Shirodkar
# 1        0.0        6              Aamir Khan
# ...      ...      ...                     ...
# 1282     0.0        1       Roop Kumar Rathod
# 1283     0.0        1        Trimala Adhikari
# 1283     0.0        1             Abhay Joshi
# 1283     0.0        1            Ashish Kumar
# 1283     0.0        1            Kumud Mishra
#
# [5103 rows x 9 columns]

# %%
# Pulled Actors information from Actor Data set

Movie_Actors_Ratings = pd.merge(Final_Movie_Actors,csv_file_actors,how = 'inner',left_on = 'Actor',right_on = 'actorName')

# %%
Movie_Actors_Ratings
# Out:
#                                  title  releaseYear  releaseDate  \
# 0                               Albela         2001  20 Apr 2001
# 1                Pyaar Diwana Hota Hai         2002  26 Apr 2002
# 2                            Jodi No.1         2001  13 Apr 2001
# 3     Aamdani Atthanni Kharcha Rupaiya         2001  21 Dec 2001
# 4                Akhiyon Se Goli Maare         2002  02 Aug 2002
# ...                                ...          ...          ...
# 3121                     Finding Fanny         2014  12 Sep 2014
# 3122                          Jannat 2         2012  04 May 2012
# 3123                        Raanjhanaa         2013  21 Jun 2013
# 3124                            Maazii         2013  27 Sep 2013
# 3125                    Raja Natwarlal         2014  29 Aug 2014
#
#                          genre  \
# 0                      Romance
# 1                      Romance
# 2                       Comedy
# 3                       Comedy
# 4                       Comedy
# ...                        ...
# 3121  Comedy | Drama | Romance
# 3122  Crime | Drama | Thriller
# 3123           Drama | Romance
# 3124                  Thriller
# 3125          Drama | Thriller
#
#                                                 writers  \
# 0     Honey Irani (screenplay) | Honey Irani (story)...
# 1     S.M. Ahale (screenplay) | Shashi (story) | Jav...
# 2     Rumi Jaffery (dialogue) | Imtiaz Patel (screen...
# 3            Anwar Khan (dialogue) | V. Shekhar (story)
# 4     Rajeev Kaul (screenplay) | Rajeev Kaul (story)...
# ...                                                 ...
# 3121                    Homi Adajania | Kersi Khambatta
# 3122            Kapil Chopra | Sanjay Masoom (dialogue)
# 3123                                    Himanshu Sharma
# 3124                    Sumit Nijhawan | Shirish Sharma
# 3125  Parveez Sheikh (story) | Sanjay Masoom (dialogue)
#
#                                     directors  sequel  hitFlop  \
# 0                               Deepak Sareen     0.0        2
# 1                                 Kirti Kumar     0.0        1
# 2                                David Dhawan     0.0        6
# 3     K. Raghavendra Rao | A.S. Ravindra Babu     0.0        3
# 4                            Harmesh Malhotra     0.0        2
# ...                                       ...     ...      ...
# 3121                            Homi Adajania     0.0        2
# 3122                           Kunal Deshmukh     1.0        5
# 3123                               Aanand Rai     0.0        6
# 3124                           Jaideep Chopra     0.0        1
# 3125                           Kunal Deshmukh     0.0        2
#
#                        Actor  actorId               actorName  movieCount  \
# 0                    Govinda      413                 Govinda          17
# 1                    Govinda      413                 Govinda          17
# 2                    Govinda      413                 Govinda          17
# 3                    Govinda      413                 Govinda          17
# 4                    Govinda      413                 Govinda          17
# ...                      ...      ...                     ...         ...
# 3121            Arjun Kapoor      390            Arjun Kapoor           5
# 3122  Mohammed Zeeshan Ayyub      468  Mohammed Zeeshan Ayyub           4
# 3123  Mohammed Zeeshan Ayyub      468  Mohammed Zeeshan Ayyub           4
# 3124  Mohammed Zeeshan Ayyub      468  Mohammed Zeeshan Ayyub           4
# 3125  Mohammed Zeeshan Ayyub      468  Mohammed Zeeshan Ayyub           4
#
#       ratingSum  normalizedMovieRank  googleHits  normalizedGoogleRank  \
# 0           680              2.95652     1430000               4.68565
# 1           680              2.95652     1430000               4.68565
# 2           680              2.95652     1430000               4.68565
# 3           680              2.95652     1430000               4.68565
# 4           680              2.95652     1430000               4.68565
# ...         ...                  ...         ...                   ...
# 3121        320              5.30435     1690000               5.35640
# 3122        230              4.66848           0               0.00000
# 3123        230              4.66848           0               0.00000
# 3124        230              4.66848           0               0.00000
# 3125        230              4.66848           0               0.00000
#
#       normalizedRating
# 0              4.78557
# 1              4.78557
# 2              4.78557
# 3              4.78557
# 4              4.78557
# ...                ...
# 3121           6.50594
# 3122           3.09077
# 3123           3.09077
# 3124           3.09077
# 3125           3.09077
#
# [3126 rows x 17 columns]

# %%
# Grouping Actor rankings griuping by Movies

Movie_Actors_Ranking_groupBy = Movie_Actors_Ratings.groupby('title')[['movieCount','ratingSum','normalizedMovieRank','googleHits','normalizedGoogleRank','normalizedRating']].describe().reset_index()


Movie_Actors_Ranking_groupBy.columns = Movie_Actors_Ranking_groupBy.columns.map('_A_'.join)


Movie_Actors_Ranking_groupBy
# Out:
#                          title_A_  movieCount_A_count  movieCount_A_mean  \
# 0                       ...Yahaan                 4.0          12.000000
# 1     13B: Fear Has a New Address                 3.0          10.333333
# 2                     16 December                 3.0          14.000000
# 3              1920: Evil Returns                 3.0           5.666667
# 4                       2 October                 2.0          12.000000
# ...                           ...                 ...                ...
# 1136     Zindagi Na Milegi Dobara                 4.0          14.500000
# 1137            Zindagi Tere Naam                 1.0          23.000000
# 1138                     Zokkomon                 3.0          17.000000
# 1139       Zor Lagaa Ke... Haiya!                 3.0          13.000000
# 1140                     Zubeidaa                 4.0          10.250000
#
#       movieCount_A_std  movieCount_A_min  movieCount_A_25%  movieCount_A_50%  \
# 0             5.416026               8.0               9.5              10.0
# 1             2.081666               8.0               9.5              11.0
# 2            16.462078               4.0               4.5               5.0
# 3             2.081666               4.0               4.5               5.0
# 4             2.828427              10.0              11.0              12.0
# ...                ...               ...               ...               ...
# 1136          5.802298               6.0              13.5              16.5
# 1137               NaN              23.0              23.0              23.0
# 1138         16.822604               4.0               7.5              11.0
# 1139          9.165151               5.0               8.0              11.0
# 1140          6.652067               6.0               6.0               7.5
#
#       movieCount_A_75%  movieCount_A_max  ratingSum_A_count  ...  \
# 0                12.50              20.0                4.0  ...
# 1                11.50              12.0                3.0  ...
# 2                19.00              33.0                3.0  ...
# 3                 6.50               8.0                3.0  ...
# 4                13.00              14.0                2.0  ...
# ...                ...               ...                ...  ...
# 1136             17.50              19.0                4.0  ...
# 1137             23.00              23.0                1.0  ...
# 1138             23.50              36.0                3.0  ...
# 1139             17.00              23.0                3.0  ...
# 1140             11.75              20.0                4.0  ...
#
#       normalizedGoogleRank_A_75%  normalizedGoogleRank_A_max  \
# 0                       1.567992                     1.79630
# 1                       2.679875                     3.93752
# 2                       0.628565                     1.25713
# 3                       0.628565                     1.25713
# 4                       1.190178                     1.23055
# ...                          ...                         ...
# 1136                    6.807520                     7.83298
# 1137                    1.409330                     1.40933
# 1138                    1.862730                     2.69148
# 1139                    1.275310                     1.40933
# 1140                    4.388977                     4.81464
#
#       normalizedRating_A_count  normalizedRating_A_mean  \
# 0                          4.0                 2.506145
# 1                          3.0                 3.212580
# 2                          3.0                 2.257037
# 3                          3.0                 2.572273
# 4                          2.0                 2.312410
# ...                        ...                      ...
# 1136                       4.0                 6.898945
# 1137                       1.0                 2.433480
# 1138                       3.0                 2.747270
# 1139                       3.0                 2.056200
# 1140                       4.0                 3.145555
#
#       normalizedRating_A_std  normalizedRating_A_min  normalizedRating_A_25%  \
# 0                   0.341191                 2.18903                2.222112
# 1                   1.611181                 2.07413                2.290815
# 2                   0.392733                 1.89206                2.049245
# 3                   0.373660                 2.20432                2.382715
# 4                   0.188359                 2.17922                2.245815
# ...                      ...                     ...                     ...
# 1136                2.302115                 3.76953                5.911725
# 1137                     NaN                 2.43348                2.433480
# 1138                0.606599                 2.39385                2.397055
# 1139                0.338121                 1.78055                1.867560
# 1140                1.580324                 1.59135                2.036347
#
#       normalizedRating_A_50%  normalizedRating_A_75%  normalizedRating_A_max
# 0                   2.515615                2.799648                 2.80432
# 1                   2.507500                3.781805                 5.05611
# 2                   2.206430                2.439525                 2.67262
# 3                   2.561110                2.756250                 2.95139
# 4                   2.312410                2.379005                 2.44560
# ...                      ...                     ...                     ...
# 1136                7.438865                8.426085                 8.94852
# 1137                2.433480                2.433480                 2.43348
# 1138                2.400260                2.923980                 3.44770
# 1139                1.954570                2.194025                 2.43348
# 1140                2.941995                4.051203                 5.10688
#
# [1141 rows x 49 columns]

# %% [markdown]
# # Creating multiple rows wirh each director

# %%
Final_Movie_Directors = Final_Movie.copy()

# %%
# Split strings into list

Final_Movie_Directors['Director'] = Final_Movie['directors'].str.split('|')

# Convert list into seperate rows

Final_Movie_Directors = Final_Movie_Directors.explode('Director')

#Removed un-necessary columns

Final_Movie_Directors = Final_Movie_Directors.drop(['directors','imdbId'],axis = 'columns')

# Remove all  spaces

#Final_Movie_Actors['Director'] = Final_Movie_Actors['Director'].str.strip()

Final_Movie_Directors
# Out:
#                                   title  releaseYear  releaseDate  \
# 0                                Albela         2001  20 Apr 2001
# 1     Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2              Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 2              Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3                Hum Tumhare Hain Sanam         2002  24 May 2002
# ...                                 ...          ...          ...
# 1279            Sanam Hum Aapke Hain...         2009     1-Jan-09
# 1280                           9 Eleven         2011     7-Oct-11
# 1281                     Hum Do Anjaane         2011    27-May-11
# 1282                            Koi Hai         2003     6-Jun-03
# 1283                              Hansa         2012    28-Dec-12
#
#                             genre  \
# 0                         Romance
# 1     Adventure | Drama | Musical
# 2                 Action | Comedy
# 2                 Action | Comedy
# 3                 Drama | Romance
# ...                           ...
# 1279              Drama | Romance
# 1280                     Thriller
# 1281       Action | Crime | Drama
# 1282               Drama | Horror
# 1283                        Drama
#
#                                                 writers  \
# 0     Honey Irani (screenplay) | Honey Irani (story)...
# 1     Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                   NaN
# 2                                                   NaN
# 3     K.S. Adiyaman | Arun Kumar (assistant dialogue...
# ...                                                 ...
# 1279  Dhananjay (dialogues) | Murari Kishan (lyrics)...
# 1280                                     Manan Katohora
# 1281   Milind Swamy (screenplay) | Milind Swamy (story)
# 1282                    Manoj Hansraj | Rajiv S.S. Ruia
# 1283                                                NaN
#
#                                                  actors  sequel  hitFlop  \
# 0     Govinda | Aishwarya Rai Bachchan | Jackie Shro...     0.0        2
# 1     Aamir Khan | Gracy Singh | Rachel Shelley | Pa...     0.0        6
# 2     Akshay Kumar | Sridevi | Gulshan Grover | Laxm...     0.0        1
# 2     Akshay Kumar | Sridevi | Gulshan Grover | Laxm...     0.0        1
# 3     Shah Rukh Khan | Madhuri Dixit | Salman Khan |...     0.0        4
# ...                                                 ...     ...      ...
# 1279  Vikram Aditya | Narendra Bedi | Chandan | Arad...     0.0        1
# 1280  Kashmira Shah | Devasish Ray | Jyoti Singh | S...     0.0        1
# 1281  Naresh Kaura | Ankita Bhargava | Jackie Shroff...     0.0        1
# 1282  Aman Verma | Shweta Menon | Rinku Ghosh | Roop...     0.0        1
# 1283  Trimala Adhikari | Abhay Joshi | Ashish Kumar ...     0.0        1
#
#                 Director
# 0          Deepak Sareen
# 1     Ashutosh Gowariker
# 2       Pankaj Parashar
# 2             S.M. Iqbal
# 3          K.S. Adiyaman
# ...                  ...
# 1279           Ajay Ojha
# 1280      Manan Katohora
# 1281        Milind Swamy
# 1282       Rajiv S. Ruia
# 1283          Manav Kaul
#
# [1368 rows x 9 columns]

# %%
# Pulled Actors information from Director Data set

Final_Movie_Directors = pd.merge(Final_Movie_Directors,Directors,how = 'inner',left_on = 'Director',right_on = 'directorName')

# %%
Final_Movie_Directors
# Out:
#                                  title  releaseYear  releaseDate  \
# 0    Lagaan: Once Upon a Time in India         2001  08 May 2002
# 1                               Swades         2004  17 Dec 2004
# 2                         Jodhaa Akbar         2008  15 Feb 2008
# 3                 What's Your Raashee?         2009  02 Oct 2009
# 4             Khelein Hum Jee Jaan Sey         2010  03 Dec 2010
# ..                                 ...          ...          ...
# 519                            Riyasat         2014  18 Jul 2014
# 520         It's Rocking: Dard-E-Disco         2012  09 Nov 2012
# 521                             Ya Rab         2014  07 Feb 2014
# 522                   Duplicate Sholay         2002    26-Apr-02
# 523                            Darwaza         2002    27-Sep-02
#
#                               genre  \
# 0       Adventure | Drama | Musical
# 1                             Drama
# 2    Action | Adventure | Biography
# 3          Comedy | Drama | Romance
# 4          Action | Drama | History
# ..                              ...
# 519                           Crime
# 520                          Comedy
# 521                           Drama
# 522                          Comedy
# 523                          Horror
#
#                                                writers  \
# 0    Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 1    M.G. Sathya (story) | Ashutosh Gowariker (stor...
# 2    Haidar Ali (story) | Haidar Ali (screenplay) |...
# 3    Ashutosh Gowariker (screenplay) | Naushil Meht...
# 4    Javed Akhtar (lyrics) | Ashutosh Gowariker (sc...
# ..                                                 ...
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                       Bashir Babar
#
#                                                 actors  sequel  hitFlop  \
# 0    Aamir Khan | Gracy Singh | Rachel Shelley | Pa...     0.0        6
# 1    Shah Rukh Khan | Gayatri Joshi | Kishori Balal...     0.0        2
# 2    Hrithik Roshan | Aishwarya Rai Bachchan | Sonu...     0.0        5
# 3    Harman Baweja | Priyanka Chopra | Anjan Srivas...     0.0        1
# 4    Abhishek Bachchan | Deepika Padukone | Sikande...     0.0        1
# ..                                                 ...     ...      ...
# 519  Rajesh Khanna | Aryeman Ramsay | Raza Murad | ...     0.0        1
# 520  Asrani | Arun Bakshi | Dinesh Hingoo | Preeti ...     0.0        1
# 521  Indrapal Ahuja | Neha Baam | Vikram Dahiya | R...     0.0        1
# 522            Devaraj | Dimple | Feroz | Reena Kapoor     0.0        2
# 523  Arun Mathur | Anil Nagrath | Amit Pachori | Sapna     0.0        1
#
#                   Director  directorId           directorName  movieCount  \
# 0       Ashutosh Gowariker          31     Ashutosh Gowariker           5
# 1       Ashutosh Gowariker          31     Ashutosh Gowariker           5
# 2       Ashutosh Gowariker          31     Ashutosh Gowariker           5
# 3       Ashutosh Gowariker          31     Ashutosh Gowariker           5
# 4       Ashutosh Gowariker          31     Ashutosh Gowariker           5
# ..                     ...         ...                    ...         ...
# 519            Ashok Tyagi         109            Ashok Tyagi           3
# 520            Ashok Tyagi         109            Ashok Tyagi           3
# 521  Hasnain Hyderabadwala          93  Hasnain Hyderabadwala           4
# 522             Kanti Shah          97             Kanti Shah           6
# 523             Kanti Shah          97             Kanti Shah           6
#
#      ratingSum  normalizedMovieRank  googleHits  normalizedGoogleRank  \
# 0          250              3.13158      460000               4.41586
# 1          250              3.13158      460000               4.41586
# 2          250              3.13158      460000               4.41586
# 3          250              3.13158      460000               4.41586
# 4          250              3.13158      460000               4.41586
# ..         ...                  ...         ...                   ...
# 519         60              1.00000       51200               1.37213
# 520         60              1.00000       51200               1.37213
# 521        100              1.35526        1780               1.00417
# 522        130              1.11842       93300               1.68558
# 523        130              1.11842       93300               1.68558
#
#      normalizedRating
# 0             3.74808
# 1             3.74808
# 2             3.74808
# 3             3.74808
# 4             3.74808
# ..                ...
# 519           1.07152
# 520           1.07152
# 521           1.34663
# 522           1.24841
# 523           1.24841
#
# [524 rows x 17 columns]

# %%
Movie_Directors_Ranking_groupBy = Final_Movie_Directors.groupby('title')[['movieCount','ratingSum','normalizedMovieRank','googleHits','normalizedGoogleRank','normalizedRating']].describe().reset_index()

# %%
# Combining header and first row

Movie_Directors_Ranking_groupBy.columns = Movie_Directors_Ranking_groupBy.columns.map('_B_'.join)

# %%
Movie_Directors_Ranking_groupBy
# Out:
#                      title_B_  movieCount_B_count  movieCount_B_mean  \
# 0                   ...Yahaan                 1.0                3.0
# 1                 16 December                 1.0                5.0
# 2                        1920                 1.0               16.0
# 3    23rd March 1931: Shaheed                 1.0                5.0
# 4                 3 Bachelors                 1.0                3.0
# ..                        ...                 ...                ...
# 519                     Zinda                 1.0                5.0
# 520            Zindaggi Rocks                 1.0                3.0
# 521             Zindagi 50 50                 1.0                6.0
# 522  Zindagi Na Milegi Dobara                 1.0                3.0
# 523         Zindagi Tere Naam                 1.0                6.0
#
#      movieCount_B_std  movieCount_B_min  movieCount_B_25%  movieCount_B_50%  \
# 0                 NaN               3.0               3.0               3.0
# 1                 NaN               5.0               5.0               5.0
# 2                 NaN              16.0              16.0              16.0
# 3                 NaN               5.0               5.0               5.0
# 4                 NaN               3.0               3.0               3.0
# ..                ...               ...               ...               ...
# 519               NaN               5.0               5.0               5.0
# 520               NaN               3.0               3.0               3.0
# 521               NaN               6.0               6.0               6.0
# 522               NaN               3.0               3.0               3.0
# 523               NaN               6.0               6.0               6.0
#
#      movieCount_B_75%  movieCount_B_max  ratingSum_B_count  ...  \
# 0                 3.0               3.0                1.0  ...
# 1                 5.0               5.0                1.0  ...
# 2                16.0              16.0                1.0  ...
# 3                 5.0               5.0                1.0  ...
# 4                 3.0               3.0                1.0  ...
# ..                ...               ...                ...  ...
# 519               5.0               5.0                1.0  ...
# 520               3.0               3.0                1.0  ...
# 521               6.0               6.0                1.0  ...
# 522               3.0               3.0                1.0  ...
# 523               6.0               6.0                1.0  ...
#
#      normalizedGoogleRank_B_75%  normalizedGoogleRank_B_max  \
# 0                       1.19790                     1.19790
# 1                       5.02639                     5.02639
# 2                       3.64152                     3.64152
# 3                       1.03090                     1.03090
# 4                       1.10111                     1.10111
# ..                          ...                         ...
# 519                     7.96737                     7.96737
# 520                     1.47041                     1.47041
# 521                     1.03879                     1.03879
# 522                     1.72505                     1.72505
# 523                     1.02085                     1.02085
#
#      normalizedRating_B_count  normalizedRating_B_mean  \
# 0                         1.0                  3.81346
# 1                         1.0                  2.34056
# 2                         1.0                  2.90282
# 3                         1.0                  1.28246
# 4                         1.0                  1.01857
# ..                        ...                      ...
# 519                       1.0                  3.47027
# 520                       1.0                  1.09071
# 521                       1.0                  1.12207
# 522                       1.0                  3.45377
# 523                       1.0                  1.11856
#
#      normalizedRating_B_std  normalizedRating_B_min  normalizedRating_B_25%  \
# 0                       NaN                 3.81346                 3.81346
# 1                       NaN                 2.34056                 2.34056
# 2                       NaN                 2.90282                 2.90282
# 3                       NaN                 1.28246                 1.28246
# 4                       NaN                 1.01857                 1.01857
# ..                      ...                     ...                     ...
# 519                     NaN                 3.47027                 3.47027
# 520                     NaN                 1.09071                 1.09071
# 521                     NaN                 1.12207                 1.12207
# 522                     NaN                 3.45377                 3.45377
# 523                     NaN                 1.11856                 1.11856
#
#      normalizedRating_B_50%  normalizedRating_B_75%  normalizedRating_B_max
# 0                   3.81346                 3.81346                 3.81346
# 1                   2.34056                 2.34056                 2.34056
# 2                   2.90282                 2.90282                 2.90282
# 3                   1.28246                 1.28246                 1.28246
# 4                   1.01857                 1.01857                 1.01857
# ..                      ...                     ...                     ...
# 519                 3.47027                 3.47027                 3.47027
# 520                 1.09071                 1.09071                 1.09071
# 521                 1.12207                 1.12207                 1.12207
# 522                 3.45377                 3.45377                 3.45377
# 523                 1.11856                 1.11856                 1.11856
#
# [524 rows x 49 columns]

# %% [markdown]
# # Getting Directors ranking dataframe combined with Actors Ranking Dataframe

# %%
Actor_Director_Rankings = pd.merge(Movie_Directors_Ranking_groupBy,Movie_Actors_Ranking_groupBy,how = 'inner',left_on = 'title_B_',right_on = 'title_A_')

# %%
Actor_Director_Rankings
# Out:
#                      title_B_  movieCount_B_count  movieCount_B_mean  \
# 0                   ...Yahaan                 1.0                3.0
# 1                 16 December                 1.0                5.0
# 2    23rd March 1931: Shaheed                 1.0                5.0
# 3                 3 Bachelors                 1.0                3.0
# 4                    3 Idiots                 1.0                3.0
# ..                        ...                 ...                ...
# 494                     Zinda                 1.0                5.0
# 495            Zindaggi Rocks                 1.0                3.0
# 496             Zindagi 50 50                 1.0                6.0
# 497  Zindagi Na Milegi Dobara                 1.0                3.0
# 498         Zindagi Tere Naam                 1.0                6.0
#
#      movieCount_B_std  movieCount_B_min  movieCount_B_25%  movieCount_B_50%  \
# 0                 NaN               3.0               3.0               3.0
# 1                 NaN               5.0               5.0               5.0
# 2                 NaN               5.0               5.0               5.0
# 3                 NaN               3.0               3.0               3.0
# 4                 NaN               3.0               3.0               3.0
# ..                ...               ...               ...               ...
# 494               NaN               5.0               5.0               5.0
# 495               NaN               3.0               3.0               3.0
# 496               NaN               6.0               6.0               6.0
# 497               NaN               3.0               3.0               3.0
# 498               NaN               6.0               6.0               6.0
#
#      movieCount_B_75%  movieCount_B_max  ratingSum_B_count  ...  \
# 0                 3.0               3.0                1.0  ...
# 1                 5.0               5.0                1.0  ...
# 2                 5.0               5.0                1.0  ...
# 3                 3.0               3.0                1.0  ...
# 4                 3.0               3.0                1.0  ...
# ..                ...               ...                ...  ...
# 494               5.0               5.0                1.0  ...
# 495               3.0               3.0                1.0  ...
# 496               6.0               6.0                1.0  ...
# 497               3.0               3.0                1.0  ...
# 498               6.0               6.0                1.0  ...
#
#      normalizedGoogleRank_A_75%  normalizedGoogleRank_A_max  \
# 0                      1.567992                     1.79630
# 1                      0.628565                     1.25713
# 2                      2.650210                     2.76888
# 3                      1.329360                     1.32936
# 4                      7.652403                     8.58112
# ..                          ...                         ...
# 494                    5.698220                     7.72979
# 495                    2.125868                     2.37417
# 496                    1.145345                     1.27261
# 497                    6.807520                     7.83298
# 498                    1.409330                     1.40933
#
#      normalizedRating_A_count  normalizedRating_A_mean  \
# 0                         4.0                 2.506145
# 1                         3.0                 2.257037
# 2                         3.0                 2.812260
# 3                         1.0                 3.690440
# 4                         4.0                 6.709300
# ..                        ...                      ...
# 494                       4.0                 4.592557
# 495                       2.0                 3.005505
# 496                       3.0                 1.528100
# 497                       4.0                 6.898945
# 498                       1.0                 2.433480
#
#      normalizedRating_A_std  normalizedRating_A_min  normalizedRating_A_25%  \
# 0                  0.341191                 2.18903                2.222112
# 1                  0.392733                 1.89206                2.049245
# 2                  0.502666                 2.42722                2.527930
# 3                       NaN                 3.69044                3.690440
# 4                  2.862597                 3.69044                4.714692
# ..                      ...                     ...                     ...
# 494                2.093682                 2.05523                3.658565
# 495                0.233805                 2.84018                2.922842
# 496                0.472574                 1.00000                1.336580
# 497                2.302115                 3.76953                5.911725
# 498                     NaN                 2.43348                2.433480
#
#      normalizedRating_A_50%  normalizedRating_A_75%  normalizedRating_A_max
# 0                  2.515615                2.799648                 2.80432
# 1                  2.206430                2.439525                 2.67262
# 2                  2.628640                3.004780                 3.38092
# 3                  3.690440                3.690440                 3.69044
# 4                  6.573380                8.567987                10.00000
# ..                      ...                     ...                     ...
# 494                4.597825                5.531817                 7.11935
# 495                3.005505                3.088167                 3.17083
# 496                1.673160                1.792150                 1.91114
# 497                7.438865                8.426085                 8.94852
# 498                2.433480                2.433480                 2.43348
#
# [499 rows x 98 columns]

# %%
Movie_filtered = Final_Movie.copy()

# %%
Movie_filtered = Movie_filtered.drop(['imdbId','writers','actors','directors'],axis = 1)

# %%
Movie_filtered
# Out:
#                                   title  releaseYear  releaseDate  \
# 0                                Albela         2001  20 Apr 2001
# 1     Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2              Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3                Hum Tumhare Hain Sanam         2002  24 May 2002
# 4                            One 2 Ka 4         2001  30 Mar 2001
# ...                                 ...          ...          ...
# 1279            Sanam Hum Aapke Hain...         2009     1-Jan-09
# 1280                           9 Eleven         2011     7-Oct-11
# 1281                     Hum Do Anjaane         2011    27-May-11
# 1282                            Koi Hai         2003     6-Jun-03
# 1283                              Hansa         2012    28-Dec-12
#
#                             genre  sequel  hitFlop
# 0                         Romance     0.0        2
# 1     Adventure | Drama | Musical     0.0        6
# 2                 Action | Comedy     0.0        1
# 3                 Drama | Romance     0.0        4
# 4         Action | Comedy | Drama     0.0        1
# ...                           ...     ...      ...
# 1279              Drama | Romance     0.0        1
# 1280                     Thriller     0.0        1
# 1281       Action | Crime | Drama     0.0        1
# 1282               Drama | Horror     0.0        1
# 1283                        Drama     0.0        1
#
# [1284 rows x 6 columns]

# %%
Combined_data = pd.merge(Movie_filtered,Actor_Director_Rankings,how = 'inner',left_on ='title',right_on = 'title_B_')

# %%
print(Combined_data.columns[20:35])
# Out:
# Index(['ratingSum_B_50%', 'ratingSum_B_75%', 'ratingSum_B_max',
#        'normalizedMovieRank_B_count', 'normalizedMovieRank_B_mean',
#        'normalizedMovieRank_B_std', 'normalizedMovieRank_B_min',
#        'normalizedMovieRank_B_25%', 'normalizedMovieRank_B_50%',
#        'normalizedMovieRank_B_75%', 'normalizedMovieRank_B_max',
#        'googleHits_B_count', 'googleHits_B_mean', 'googleHits_B_std',
#        'googleHits_B_min'],
#       dtype='object')

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# Movie_B_ - stands for director details
#
# Movie_A_ - stands for actor details.

# %%
Combined_data.drop(['movieCount_B_std','title_B_','movieCount_B_25%','movieCount_B_count','movieCount_B_75%','normalizedRating_A_75%','normalizedRating_A_25%','normalizedRating_A_std','normalizedGoogleRank_A_75%','normalizedGoogleRank_A_25%',
                   'normalizedGoogleRank_A_std','ratingSum_B_std','ratingSum_B_25%','ratingSum_B_75%',
                    'normalizedMovieRank_B_std','normalizedMovieRank_B_25%','normalizedMovieRank_B_75%',
                   'googleHits_B_std','googleHits_B_25%','googleHits_B_75%','normalizedGoogleRank_B_std','normalizedGoogleRank_B_25%','normalizedGoogleRank_B_75%',
                   'normalizedRating_B_std','normalizedRating_B_25%','normalizedRating_B_75%'],axis = 1).head(1)
# Out:
#                                title  releaseYear  releaseDate  \
# 0  Lagaan: Once Upon a Time in India         2001  08 May 2002
#
#                          genre  sequel  hitFlop  movieCount_B_mean  \
# 0  Adventure | Drama | Musical     0.0        6                5.0
#
#    movieCount_B_min  movieCount_B_50%  movieCount_B_max  ratingSum_B_count  \
# 0               5.0               5.0               5.0                1.0
#
#    ratingSum_B_mean  ratingSum_B_min  ratingSum_B_50%  ratingSum_B_max  \
# 0             250.0            250.0            250.0            250.0
#
#    normalizedMovieRank_B_count  normalizedMovieRank_B_mean  \
# 0                          1.0                     3.13158
#
#    normalizedMovieRank_B_min  normalizedMovieRank_B_50%  \
# 0                    3.13158                    3.13158
#
#    normalizedMovieRank_B_max  googleHits_B_count  googleHits_B_mean  \
# 0                    3.13158                 1.0           460000.0
#
#    googleHits_B_min  googleHits_B_50%  googleHits_B_max  \
# 0          460000.0          460000.0          460000.0
#
#    normalizedGoogleRank_B_count  normalizedGoogleRank_B_mean  \
# 0                           1.0                      4.41586
#
#    normalizedGoogleRank_B_min  normalizedGoogleRank_B_50%  \
# 0                     4.41586                     4.41586
#
#    normalizedGoogleRank_B_max  normalizedRating_B_count  \
# 0                     4.41586                       1.0
#
#    normalizedRating_B_mean  normalizedRating_B_min  normalizedRating_B_50%  \
# 0                  3.74808                 3.74808                 3.74808
#
#    normalizedRating_B_max                           title_A_  \
# 0                 3.74808  Lagaan: Once Upon a Time in India
#
#    movieCount_A_count  movieCount_A_mean  movieCount_A_std  movieCount_A_min  \
# 0                 2.0               10.0          1.414214               9.0
#
#    movieCount_A_25%  movieCount_A_50%  movieCount_A_75%  movieCount_A_max  \
# 0               9.5              10.0              10.5              11.0
#
#    ratingSum_A_count  ratingSum_A_mean  ratingSum_A_std  ratingSum_A_min  \
# 0                2.0             780.0       551.543289            390.0
#
#    ratingSum_A_25%  ratingSum_A_50%  ratingSum_A_75%  ratingSum_A_max  \
# 0            585.0            780.0            975.0           1170.0
#
#    normalizedMovieRank_A_count  normalizedMovieRank_A_mean  \
# 0                          2.0                    6.365615
#
#    normalizedMovieRank_A_std  normalizedMovieRank_A_min  \
# 0                   4.360027                    3.28261
#
#    normalizedMovieRank_A_25%  normalizedMovieRank_A_50%  \
# 0                   4.824112                   6.365615
#
#    normalizedMovieRank_A_75%  normalizedMovieRank_A_max  googleHits_A_count  \
# 0                   7.907117                    9.44862                 2.0
#
#    googleHits_A_mean  googleHits_A_std  googleHits_A_min  googleHits_A_25%  \
# 0          1332000.0      1.595233e+06          204000.0          768000.0
#
#    googleHits_A_50%  googleHits_A_75%  googleHits_A_max  \
# 0         1332000.0         1896000.0         2460000.0
#
#    normalizedGoogleRank_A_count  normalizedGoogleRank_A_mean  \
# 0                           2.0                     4.432835
#
#    normalizedGoogleRank_A_min  normalizedGoogleRank_A_50%  \
# 0                     1.52284                    4.432835
#
#    normalizedGoogleRank_A_max  normalizedRating_A_count  \
# 0                     7.34283                       2.0
#
#    normalizedRating_A_mean  normalizedRating_A_min  normalizedRating_A_50%  \
# 0                  6.58442                 3.16884                 6.58442
#
#    normalizedRating_A_max
# 0                    10.0
